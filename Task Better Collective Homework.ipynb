# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# Specify the directory containing the CSV files
data_directory = r'C:\Users\Danica Filipovic\Desktop'

# Get a list of all CSV files in the directory
csv_files = [file for file in os.listdir(data_directory) if file.endswith('.csv')]

# Loop through each CSV file in the directory
for csv_file in csv_files:
    # Construct the full path to the CSV file
    file_path = os.path.join(data_directory, csv_file)

    # Read the data from the CSV file into a Pandas DataFrame
    df = pd.read_csv(file_path)

    # Extract the season from the CSV file name
    # (Assuming the file name contains the season information, adjust this based on your file naming convention)
    season = csv_file.split('_')[0]

     # Visualize the average age per team and season using a bar chart
    average_age_per_team_season.plot(kind='bar', title=f'Average Age per Team and Season - {season}')
    plt.ylabel('Average Age')
    plt.xlabel('Team')
    plt.show()
    
    # Calculate the average age per team
    average_age_per_team_season = df.groupby(['Tm'])['Age'].mean()

    # Print the result
    print(f"\nAverage age per team for {season}:")
    print(average_age_per_team_season)

    # Calculate the average and maximum age per season
    average_max_age_per_season = df['Age'].agg(['mean', 'max'])

    # Print the result
    print(f"\nAverage and maximum age per season for {season}:")
    print(average_max_age_per_season)
# Out:
# Average age per team for Team2020.csv:
# Tm
# ANA    26.000000
# ARI    26.680000
# BOS    26.257143
# BUF    25.812500
# CAR    25.481481
# CBJ    24.848485
# CGY    26.714286
# CHI    25.354839
# COL    25.741935
# DAL    27.333333
# DET    26.735294
# EDM    26.419355
# FLA    26.500000
# LAK    26.031250
# MIN    27.296296
# MTL    26.382353
# NJD    25.437500
# NSH    27.379310
# NYI    27.214286
# NYR    24.851852
# OTT    25.216216
# PHI    25.903226
# PIT    27.323529
# SJS    26.617647
# STL    26.741935
# TBL    27.034483
# TOR    25.090909
# TOT    27.553846
# VAN    26.655172
# VEG    26.933333
# WPG    25.906250
# WSH    27.629630
# Name: Age, dtype: float64
#
# Average and maximum age per season for Team2020.csv:
# mean    26.36122
# max     42.00000
# Name: Age, dtype: float64
# Average age per team for Team2021.csv:
# Tm
# ANA    26.212121
# ARI    26.032258
# BOS    26.444444
# BUF    25.696970
# CAR    25.928571
# CBJ    26.090909
# CGY    26.655172
# CHI    25.058824
# COL    26.114286
# DAL    27.461538
# DET    27.000000
# EDM    26.714286
# FLA    25.909091
# LAK    24.687500
# MIN    28.000000
# MTL    27.068966
# NJD    24.468750
# NSH    26.457143
# NYI    28.107143
# NYR    24.500000
# OTT    25.243243
# PHI    25.454545
# PIT    27.375000
# SJS    26.054054
# STL    26.933333
# TBL    26.714286
# TOR    27.000000
# TOT    27.448276
# VAN    26.057143
# VEG    26.961538
# WPG    26.555556
# WSH    28.862069
# Name: Age, dtype: float64
#
# Average and maximum age per season for Team2021.csv:
# mean    26.398058
# max     43.000000
# Name: Age, dtype: float64
# Average age per team for Team2022.csv:
# Tm
# ANA    25.947368
# ARI    26.157895
# BOS    27.303030
# BUF    24.941176
# CAR    26.344828
# CBJ    24.812500
# CGY    27.821429
# CHI    24.945946
# COL    26.371429
# DAL    27.724138
# DET    26.205882
# EDM    27.515152
# FLA    26.828571
# LAK    25.333333
# MIN    26.676471
# MTL    26.225000
# NJD    24.117647
# NSH    26.233333
# NYI    29.000000
# NYR    25.843750
# OTT    25.368421
# PHI    26.512821
# PIT    27.645161
# SEA    26.857143
# SJS    25.685714
# STL    27.387097
# TBL    27.533333
# TOR    27.029412
# TOT    27.153846
# VAN    26.636364
# VEG    25.944444
# WPG    25.885714
# WSH    27.771429
# Name: Age, dtype: float64
#
# Average and maximum age per season for Team2022.csv:
# mean    26.464716
# max     44.000000
# Name: Age, dtype: float64
